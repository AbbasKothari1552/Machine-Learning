# %% [markdown]
# # Fetch California Housing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()

# %%
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
df = pd.DataFrame(data.data)

# %%
df
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
df.columns = data.feature_names

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
# independent & dependent features
X = df
y = data.target

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
X_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 18032  5.5944      19.0  6.240143   1.053763       632.0  2.265233     37.24
# 12346  2.5212      21.0  5.897924   1.335063      3623.0  2.089389     33.82
# 495    5.3794      52.0  6.861017   1.123729      1316.0  2.230508     37.86
# 8262   3.1149      45.0  3.715026   1.110535      1047.0  1.808290     33.77
# 3078   6.2885       6.0  6.909449   1.102362       664.0  2.614173     35.47
# ...       ...       ...       ...        ...         ...       ...       ...
# 10129  5.4617      17.0  5.487850   1.037383      1381.0  2.581308     33.92
# 15661  0.8543      27.0  2.297872   1.175532      1211.0  1.610372     37.78
# 15120  3.1142       5.0  4.548066   1.093923      2770.0  3.060773     32.85
# 13468  3.3438       8.0  5.455172   1.124138      2184.0  3.012414     34.09
# 17612  5.3077      18.0  6.065767   1.119730      1321.0  2.227656     37.29
#
#        Longitude
# 18032    -121.94
# ...

# %%
# Standardize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## apply ridge regression

# %%
# import Ridge & GridSearchCV it is for selecting the best alpha value (lambda) from the given
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge_reg = Ridge()

# %%
# Possible Parameters for the value of alpha.
parameters = {'alpha' : [1,2,5,9,10,15,18,20,27,35,30,37,40,50,55]}

# %%
ridge_cv = GridSearchCV(ridge_reg,parameters,scoring='neg_mean_squared_error',cv=5)

# %%
ridge_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 5, 9, 10, 15, 18, 20, 27, 35, 30, 37,
#                                    40, 50, 55]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_cv.best_params_)
# Out:
# {'alpha': 30}

# %%
print(ridge_cv.best_score_)
# Out:
# -0.5269682508264226

# %%
# predict the test model
ridge_pred = ridge_cv.predict(X_test)

# %%
import seaborn as sns
sns.displot(ridge_pred-y_test,kind = 'kde')
# Out:
# C:\Users\ask50\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,ridge_pred)

# %%
score
# Out:
# 0.5996710704172254

# %% [markdown]
# # Lasso Regression

# %%
# import Lasso
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso()

# %%
# Possible Parameters for the value of alpha.
parameters = {'alpha' : [1,2,5,9,10,15,18,20,27,35,30,37,40,50,55]}

# %%
lasso_cv = GridSearchCV(lasso_reg,parameters,scoring='neg_mean_squared_error',cv=5)

# %%
lasso_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1, 2, 5, 9, 10, 15, 18, 20, 27, 35, 30, 37,
#                                    40, 50, 55]},
#              scoring='neg_mean_squared_error')

# %%
print(lasso_cv.best_params_)
# Out:
# {'alpha': 1}

# %%
print(lasso_cv.best_score_)
# Out:
# -1.3276801160819027

# %%
# predict
lasso_pred = lasso_cv.predict(X_test)

# %%
sns.displot(lasso_pred-y_test,kind='kde')
# Out:
# C:\Users\ask50\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# r2_score
from sklearn.metrics import r2_score
score = r2_score(y_test,lasso_pred)
